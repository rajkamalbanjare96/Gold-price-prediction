# %% [markdown]
# <a href="https://colab.research.google.com/github/rajkamalbanjare96/Gold-price-prediction/blob/main/Copy_of_Gold_price_predict_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import plotly.express as px
from sklearn.ensemble import RandomForestRegressor

# %%
data=pd.read_csv('/content/sample_data/FINAL_USO.csv')
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1     2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2     2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3     2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4     2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
# ...          ...         ...         ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000  120.019997  120.019997
# 1714  2018-12-26  120.620003  121.000000  119.570000  119.660004  119.660004
# 1715  2018-12-27  120.570000  120.900002  120.139999  120.570000  120.570000
# 1716  2018-12-28  120.800003  121.080002  120.720001  121.059998  121.059998
# 1717  2018-12-31  120.980003  121.260002  120.830002  121.250000  121.250000
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x = data['Open'].values.reshape(-1, 1)
y = data['Volume'].values.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 19000835705894.555

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1718 non-null   object
#  1   Open           1718 non-null   float64
#  2   High           1718 non-null   float64
#  3   Low            1718 non-null   float64
#  4   Close          1718 non-null   float64
#  5   Adj Close      1718 non-null   float64
#  6   Volume         1718 non-null   int64
#  7   SP_open        1718 non-null   float64
#  8   SP_high        1718 non-null   float64
#  9   SP_low         1718 non-null   float64
#  10  SP_close       1718 non-null   float64
#  11  SP_Ajclose     1718 non-null   float64
#  12  SP_volume      1718 non-null   int64
#  13  DJ_open        1718 non-null   float64
#  14  DJ_high        1718 non-null   float64
#  15  DJ_low         1718 non-null   float64
#  16  DJ_close       1718 non-null   float64
# ...

# %%
data.shape
# Out:
# (1718, 81)

# %%
correleation = data.corr()
correleation
# Out:
# <ipython-input-22-62e16118a47e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correleation = data.corr()
#                    Open      High       Low     Close  Adj Close    Volume  \
# Open           1.000000  0.999515  0.999442  0.998976   0.998976  0.251921
# High           0.999515  1.000000  0.999262  0.999535   0.999535  0.261064
# Low            0.999442  0.999262  1.000000  0.999532   0.999532  0.237031
# Close          0.998976  0.999535  0.999532  1.000000   1.000000  0.246778
# Adj Close      0.998976  0.999535  0.999532  1.000000   1.000000  0.246778
# ...                 ...       ...       ...       ...        ...       ...
# USO_High       0.634864  0.637208  0.633623  0.635311   0.635311  0.083064
# USO_Low        0.634277  0.636538  0.633140  0.634732   0.634732  0.080475
# ...

# %%
fig = px.line(data, x=data["Date"], y=data["Adj Close"], title="Relation Between prediction value and Date ")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state =44)

# %%
print("X_TrainShape",x_train.shape)
print("X_TestShape",x_test.shape)
print("y_TrainShape",y_train.shape)
print("y_TestShape",y_test.shape)
# Out:
# X_TrainShape (1151, 1)
# X_TestShape (567, 1)
# y_TrainShape (1151, 1)
# y_TestShape (567, 1)

# %%
RandomForestRegressorModel = RandomForestRegressor(n_estimators=50,max_depth = 20 ,n_jobs=-1)

RandomForestRegressorModel.fit(x_train,y_train)
# Out:
# <ipython-input-26-6749f6d62d77>:3: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(max_depth=20, n_estimators=50, n_jobs=-1)

# %%
print('Random Forest Regressor Train Score is : ' , RandomForestRegressorModel.score(x_train, y_train))
print('Random Forest Regressor Test Score is : ' , RandomForestRegressorModel.score(x_test, y_test))
# Out:
# Random Forest Regressor Train Score is :  0.7502439256853468
# Random Forest Regressor Test Score is :  -0.820269060149353

# %%
y_pred =  RandomForestRegressorModel.predict(x_test)
print(y_pred)
print(y_pred.shape)
# Out:
# [ 5707019.84415584  5201960.          8192764.          9381427.30576441
#  10668177.71428571 11177838.4         5367191.1702002   9125796.98287534
#   8170353.27332234 10668177.71428571 10319008.88784314  8098913.72933131
#   7375586.68241368 18709406.          7444965.04666667  9603886.69933676
#   5656575.58624076  6008362.42759006  7275946.86044399  4872449.72459863
#   9376469.75        5560077.30283204  7090180.37948718 22994228.
#   9755692.          5644166.61574702  9187166.         10222324.8
#   7365213.6         6320650.          7932982.78277989  7816534.57836614
#   8655210.66666667 11112948.88784314  6368657.77777778  6922975.2609234
#   9700764.64615384  7906921.72933131  9863931.36111111  9176680.33333333
#   6837648.05592535  9498977.30576441  5130760.41574702  8120001.95948595
#   9147066.5        11756074.33333333 22131654.21052631  8329984.
#   7404147.28829143 15392353.14666667  4982417.5         7839309.73012911
# ...

# %%
y_pred= pd.DataFrame(y_pred,columns=['Expected'])
y_pred
# Out:
#          Expected
# 0    5.707020e+06
# 1    5.201960e+06
# 2    8.192764e+06
# 3    9.381427e+06
# 4    1.066818e+07
# ..            ...
# 562  6.591777e+06
# 563  7.420894e+06
# 564  7.455711e+06
# 565  7.261159e+06
# 566  1.100713e+07
#
# [567 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(y_pred, *['Expected'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# ...
